# %% [markdown]
# Before you Begin

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# %%
api_key="db8233be9f1759c8f44730f7ed253dace04220dae5d126f541b49fa61e4953ae"

url= "https://www.themuse.com/api/public/jobs?page=1"

response= requests.get(url).json()
pprint(response)
# Out:
# {'aggregations': {},
#  'items_per_page': 20,
#  'page': 1,
#  'page_count': 4712,
#  'results': [{'categories': [{'name': 'Healthcare & Medicine'}],
#               'company': {'id': 1056, 'name': 'MDA', 'short_name': 'mda'},
#               'contents': '<p><strong>Contents:</strong><br/>\n'
#                           'The Care &amp; Clinical Services Specialist will '
#                           'report to the Director of Care &amp; Clinical '
#                           'Services. The primary responsibility of this role '
#                           'is Care Center and family support and engagement. '
#                           'This individual will oversee Care Center '
#                           'responsibilities and the implementation of support, '
#                           'education and engagement programs for the community '
#                           'MDA serves in their territory. S/he is responsible '
# ...
