# %% [markdown]
# # Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
from pprint import pprint

# %matplotlib notebook

# %%
# Creating data path for datasets
job_data_path="Marks-Code\job_company_merged_data.csv"

# Reading datasets
job_data = pd.read_csv(job_data_path)
job_data.head()
# Out:
#    Unnamed: 0   job id  job level      location  \
# 0           0  3092962  Mid Level  New York, NY
# 1           1  2722893  Mid Level    Boston, MA
# 2           2  3104296  Mid Level   Atlanta, GA
# 3           3  2686925  Mid Level   Seattle, WA
# 4           4  3119346  Mid Level   Atlanta, GA
#
#                                             job name  \
# 0                                 Rate Table Analyst
# 1                      Data Scientist, Acorn AI Labs
# 2                    Advanced Analytics Specialist 2
# 3  AI/ML - Machine Learning Educator, Machine Int...
# 4                    Advanced Analytics Specialist 2
#
#                      post date  \
# 0  2020-06-13T23:41:21.301065Z
# 1  2020-06-10T23:05:28.051056Z
# 2  2020-06-12T22:39:39.785871Z
# 3  2020-05-19T11:13:51.307171Z
# 4  2020-06-12T23:35:19.533738Z
#
#                                         landing page      category  \
# 0  https://www.themuse.com/jobs/better/rate-table...  Data Science
# 1  https://www.themuse.com/jobs/medidata/data-sci...  Data Science
# 2  https://www.themuse.com/jobs/walmart/advanced-...  Data Science
# 3  https://www.themuse.com/jobs/apple/aiml-machin...  Data Science
# 4  https://www.themuse.com/jobs/walmart/advanced-...  Data Science
#
#    company id company name  content  \
# 0        1086       Better      NaN
# 1        1309     Medidata      NaN
# 2       12010      Walmart      NaN
# 3       11802        Apple      NaN
# 4       12010      Walmart      NaN
#
#                                             contents industy 1 industy 2  \
# 0  <p><strong>About Better.com:</strong><br> <br>...  Consumer   Finance
# 1  <p>Medidata: Conquering Diseases Together</p>\...       NaN       NaN
# 2  <p><strong> Position Summary... </strong><br><...       NaN       NaN
# 3  <p>Summary <br><br> Posted: May 18, 2020 <br><...       NaN       NaN
# 4  <p><strong> Position Summary... </strong><br><...       NaN       NaN
#
#                     industy 3 industy 4 industy 5 industy 6
# 0  Real Estate & Construction      Tech       NaN       NaN
# 1                         NaN       NaN       NaN       NaN
# 2                         NaN       NaN       NaN       NaN
# 3                         NaN       NaN       NaN       NaN
# 4                         NaN       NaN       NaN       NaN

# %%
#new column
job_data["job title category"]=""
job_data.columns
# Out:
# Index(['Unnamed: 0', 'job id', 'job level', 'location', 'job name',
#        'post date', 'landing page', 'category', 'company id', 'company name',
#        'content', 'contents', 'industy 1', 'industy 2', 'industy 3',
#        'industy 4', 'industy 5', 'industy 6', 'job title category'],
#       dtype='object')

# %%
#finding unique number of jobs in the dataset
job_count= job_data["job name"].value_counts()
job_count
# Out:
# Data Engineer                                            11
# Senior Data Scientist                                     8
# Data Scientist                                            7
# Data Analyst                                              6
# Bioinformatics Engineer, Algorithm                        5
#                                                          ..
# Data Engineer, Analytics (Instagram Ecosystems)           1
# Rates Options Quant                                       1
# Senior Reporting Analyst - Professional Service - EDU     1
# Director II, Data Science                                 1
#  Business Intelligence Developer                          1
# Name: job name, Length: 509, dtype: int64

# %%
job_data.loc[job_data["job name"].isna()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, job id, job level, location, job name, post date, landing page, category, company id, company name, content, contents, industy 1, industy 2, industy 3, industy 4, industy 5, industy 6, job title category]
# Index: []

# %%
cleaned_job_data.shape
# Out:
# (589, 18)

# %%
#dictionary

job_title = {}
job_title["Data Scientist"]=0
job_title["Data Engineer"]=0
job_title["Data Analyst"]=0
job_title["Managerial"]=0
job_title["Quantitive/Research"]=0
job_title["Other"]=0

data_scientist_list=["scientist","data science","science"]
data_engineer_list=["engineer","data engineer"]
data_analyst_list=["analyst","data analyst","business intelligence","analytics","analytic"]
managerial_data_list=["director","manager","vice president","head of","lead"]
quant_list=["quant","research"]

for job in job_data["job name"].tolist():
    job=job.replace("," ,"")
    job=job.replace(")" ,"")
    job=job.replace("(" ,"")
    job=job.replace("-" ,"")
    job_word=job.lower().split(" ")
    other_exists=True
    for word in job_word:
        if word in data_scientist_list:
            job_title["Data Scientist"]+=1
            other_exists=False
            break
        elif word in data_engineer_list:
            job_title["Data Engineer"]+=1
            other_exists=False
            break
        elif word in data_analyst_list:
            job_title["Data Analyst"]+=1
            other_exists=False
            break
        elif word in managerial_data_list:
            job_title["Managerial"]+=1
            other_exists=False
            break
        elif word in quant_list:
            job_title["Quantitive/Research"]+=1
            other_exists=False
            break
    if other_exists:
        job_title["Other"]+=1
print(job_title)
# Out:
# {'Data Scientist': 65, 'Data Engineer': 123, 'Data Analyst': 137, 'Managerial': 106, 'Quantitive/Research': 33, 'Other': 125}

# %%
job_title["Other"]
# Out:
# 125

# %%
job_data_df = pd.DataFrame({"count" : job_title})
job_data_df.index
# Out:
# Index(['Data Analyst', 'Data Engineer', 'Data Scientist', 'Managerial',
#        'Other', 'Quantitive/Research'],
#       dtype='object')

# %%
job_data_df.index
# Out:
# Index(['Data Analyst', 'Data Engineer', 'Data Scientist', 'Managerial',
#        'Other', 'Quantitive/Research'],
#       dtype='object')

# %%
#pie=job_data_df.plot.pie(y="count", autopct="%.1f%%")
#plt.show()

# %%
# Labels for the sections of our pie chart
labels = job_data_df.index.values

# The values of each section of the pie chart
sizes = job_data_df["count"]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue","purple","green"]

# Tells matplotlib to seperate the "Humans" section from the others
explode = (0.1, 0, 0, 0,0,0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=False, startangle=140)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# ['Data Analyst' 'Data Engineer' 'Data Scientist' 'Managerial' 'Other'
#  'Quantitive/Research']
