# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
pathFile = "Resources/cost_of_living_2020.csv"
df = pd.read_csv(pathFile)
df
# Out:
#              State  costIndex  costRank  groceryCost  housingCost  \
# 0      Mississippi       86.1         1         91.6         70.1
# 1         Arkansas       86.9         2         92.0         73.9
# 2         Oklahoma       87.0         3         95.4         71.9
# 3         Missouri       87.1         4         96.6         70.6
# 4       New Mexico       87.5         5        100.9         77.7
# 5        Tennessee       88.7         6         93.3         80.2
# 6         Michigan       88.9         7         89.3         75.2
# 7           Kansas       89.0         8         91.9         73.8
# 8          Georgia       89.2         9         96.9         73.8
# 9          Alabama       89.3        11         97.4         71.5
# 10         Wyoming       89.3        10         98.7         72.3
# 11         Indiana       90.0        12         93.3         77.3
# 12            Iowa       90.1        13         95.9         79.6
# 13        Nebraska       90.8        14         95.5         80.9
# 14            Ohio       90.8        15         98.7         73.6
# 15        Kentucky       90.9        16         89.9         77.4
# 16   West Virginia       91.1        17         92.9         79.6
# 17           Texas       91.5        18         88.9         85.3
# 18           Idaho       92.3        19         92.2         87.1
# 19       Louisiana       93.9        20         99.9         86.6
# 20        Illinois       94.5        21         94.2         87.2
# 21  North Carolina       94.9        22         96.6         83.1
# 22  South Carolina       95.9        23        101.9         85.1
# 23         Arizona       97.0        24         96.9         91.7
# 24       Wisconsin       97.3        25        100.7         91.4
# 25         Florida       97.9        26        104.0         95.4
# 26            Utah       98.4        27         98.5         93.6
# 27    North Dakota       98.8        28        108.1         90.3
# 28    South Dakota       99.8        29        107.0        109.8
# 29        Virginia      100.7        30         96.1        108.0
# 30       Minnesota      101.6        31        106.7         88.3
# 31    Pennsylvania      101.7        32        106.9        100.8
# 32        Colorado      105.6        33        102.5        119.0
# 33         Montana      106.9        34        105.1        111.6
# 34        Delaware      108.1        35        113.4         98.2
# 35          Nevada      108.5        36        108.3        121.8
# 36   New Hampshire      109.7        37        100.4        110.3
# 37      Washington      110.7        38        107.8        117.8
# 38         Vermont      114.5        39        111.3        126.7
# 39           Maine      117.5        40        107.0        123.1
# 40    Rhode Island      119.4        41        106.2        129.4
# 41      New Jersey      125.1        42        109.5        163.1
# 42     Connecticut      127.7        43        114.2        144.7
# 43        Maryland      129.7        44        108.5        184.5
# 44          Alaska      129.9        45        134.2        133.9
# 45   Massachusetts      131.6        46        113.9        170.3
# 46          Oregon      134.2        47        110.3        181.8
# 47        New York      139.1        48        114.8        204.4
# 48      California      151.7        49        121.4        227.3
# 49   Washington DC      158.4        50        115.5        267.0
# 50          Hawaii      192.9        51        169.3        318.6
#
#     utilitiesCost  transportationCost  miscCost
# 0            89.1                89.2      91.4
# 1            91.8                83.6      85.6
# 2            94.1                89.5      93.2
# 3            99.6                87.3      95.7
# 4            87.9                91.6     100.1
# 5            93.4                89.7      88.5
# 6            97.3                97.4      93.0
# 7           103.0                92.3      98.9
# 8            92.4                97.6      98.5
# 9           103.3                88.6      90.8
# 10           87.3                99.3      94.9
# 11           97.0                93.1      94.3
# 12           95.3                95.5      97.8
# 13           90.8                94.3      99.9
# 14           91.8                96.7      97.6
# 15           97.6                92.8      89.2
# 16           89.0                93.5      89.1
# 17          102.3                91.4      96.2
# 18           82.9               106.7      97.3
# 19           89.3                98.5      98.8
# 20          100.9               100.9      99.0
# 21           97.9                93.4     110.6
# 22          107.6                88.0      94.2
# 23          107.4               109.6      94.7
# 24           98.9                98.1     115.2
# 25          102.2                96.7      96.9
# 26           89.4               108.6      96.0
# 27           93.6               104.3     111.7
# 28           91.8                89.8     103.0
# 29           99.2                88.1      97.2
# 30           96.8               103.7     108.6
# 31          106.0               109.5      91.9
# 32           88.4               101.2     102.9
# 33           83.9               125.0      98.4
# 34           96.5               107.0     101.6
# 35           89.0               123.5     105.7
# 36          119.5               111.4     116.1
# 37           88.7               121.7     118.9
# 38          120.2               119.9     101.2
# 39          116.1               121.4     121.8
# 40          123.5               124.0     109.3
# 41          101.6               111.1     101.7
# 42          128.1               111.8     113.7
# 43          107.3               116.7      89.2
# 44          154.2               130.8     150.9
# 45          109.7               116.0     117.6
# 46           88.0               136.7     113.2
# 47          108.7               116.6     104.8
# 48          117.7               138.9     114.5
# 49          119.7               116.6      97.3
# 50          172.7               148.6     116.8

# %%
dcMetro = ["Washington DC", "Virginia" ]

calcDC = df[df["State"].isin(dcMetro)]
calcDC = calcDC[["State", "costIndex"]]
print(calcDC)
colDC = calcDC.mean()
colDC
# Out:
#             State  costIndex
# 29       Virginia      100.7
# 49  Washington DC      158.4
# costIndex    129.55
# dtype: float64

# %%
states=["California", "New York", "Massachusetts", "Washington","Pennsylvania", "Illinois", "Texas", "Georgia"]
# states_df = df[df["State"].str.contains(states)]

states_df = df[df["State"].isin(states)]
state_df = states_df[["State", "costIndex"]]

# %%
dcMetro_df = pd.DataFrame({"State":"Washington DC",
                           "costIndex": colDC})
dcMetro_df = dcMetro_df.set_index(["State"])
dcMetro_df
merge_df = pd.merge(state_df, dcMetro_df, on="State", how="outer")
merge_df
merge_df = merge_df.fillna(0)
merge_df["Cost Index"] = merge_df["costIndex_x"] + merge_df["costIndex_y"]
statesBar = merge_df[["State", "Cost Index"]]
statesBar = statesBar.sort_values("Cost Index", ascending=False)
statesBar
# Out:
#            State  Cost Index
# 7     California      151.70
# 6       New York      139.10
# 5  Massachusetts      131.60
# 8  Washington DC      129.55
# 4     Washington      110.70
# 3   Pennsylvania      101.70
# 2       Illinois       94.50
# 1          Texas       91.50
# 0        Georgia       89.20

# %%
ax = statesBar.plot(kind="bar", x="State", rot=45, title="Cost of Living by State", legend=False, color="purple")
ax.set(ylabel="Cost Index")
plt.tight_layout()
plt.savefig("Resources/Cost_of_Living_by_State.png")
# plt.ylabel("Cost Index")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
statesBar.loc[9] = ["California",151.70]  
# #  statesBar.index =  statesBar.index + 1  # shifting index
# #  statesBar =  statesBar.sort_index()  # sorting by index
statesBar = statesBar.sort_values("Cost Index", ascending=False)
statesBar
# Out:
#            State  Cost Index
# 7     California      151.70
# 9     California      151.70
# 6       New York      139.10
# 5  Massachusetts      131.60
# 8  Washington DC      129.55
# 4     Washington      110.70
# 3   Pennsylvania      101.70
# 2       Illinois       94.50
# 1          Texas       91.50
# 0        Georgia       89.20

# %%
cities=["San Francisco", "Los Angeles", "NYC", "Boston","Washington DC", "Seattle","Philadelphia","Chicago","Houston","Atlanta"]

# %%
rankCOL = []
costIndexList=statesBar['Cost Index']

for x in costIndexList:  
    if x >= 150 < 159: rankCOL.append(8)
    elif x >= 140 < 149 : rankCOL.append(7)
    elif x >= 130 < 139: rankCOL.append(6)
    elif x >= 120 < 129: rankCOL.append(5)
    elif x >= 110 < 119: rankCOL.append(4)
    elif x >= 100 < 109: rankCOL.append(3)
    elif x >= 90 < 99: rankCOL.append(2)
    else: rankCOL.append(1)    
rankCOL
# Out:
# [8, 8, 6, 6, 5, 4, 3, 2, 2, 1]

# %%
rankCOL_df = pd.DataFrame({"Cities": cities, "Rank COL": rankCOL})
rankCOL_df
# Out:
#           Cities  Rank COL
# 0  San Francisco         8
# 1    Los Angeles         8
# 2            NYC         6
# 3         Boston         6
# 4  Washington DC         5
# 5        Seattle         4
# 6   Philadelphia         3
# 7        Chicago         2
# 8        Houston         2
# 9        Atlanta         1

# %%
outFile = "Resources/rankCOL.csv"
rankCOL_df.to_csv(outFile)
