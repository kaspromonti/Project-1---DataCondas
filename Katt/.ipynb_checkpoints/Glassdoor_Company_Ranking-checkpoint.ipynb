# %%
# %matplotlib notebook

# %%
# Dependencies and set up
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# File path and read csv
pathFile = "Resources/glassdoor_big-data-business-analytics-company-ranking-05-06-2020-final.csv"
df = pd.read_csv(pathFile)
df
# Out:
#                      Company Name  \
# 0                        Fivetran
# 1                       Matillion
# 2                  Splice Machine
# 3                         Dataiku
# 4                         AtScale
# ..                            ...
# 99             Striim - 9 reviews
# 100           Tellius - 9 reviews
# 101         Timescale - 6 reviews
# 102      Unravel Data - 7 reviews
# 103  Yellowbrick Data - 2 reviews
#
#      % of employees who would recommend this company to a friend   \
# 0                                                 100%
# 1                                                 100%
# 2                                                 100%
# 3                                                  99%
# 4                                                  98%
# ..                                                 ...
# 99                                                 89%
# 100                                               100%
# ...

# %%
# df = df.set_index(["Company Name"])
# df

# %%
print(df.columns.tolist())
# Out:
# ['Company Name', ' % of employees who would recommend this company to a friend ', ' % of employees who approve of the CEO as of May 6, 2020 on Glassdoor', '2020 CRN 100 Categories ']

# %%
df.dtypes
# Out:
# Company Name                                                             object
#  % of employees who would recommend this company to a friend             object
#  % of employees who approve of the CEO as of May 6, 2020 on Glassdoor    object
# 2020 CRN 100 Categories                                                  object
# dtype: object

# %%
df[' % of employees who would recommend this company to a friend '] = df[' % of employees who would recommend this company to a friend '].replace("%","").astype(float)
df[' % of employees who approve of the CEO as of May 6, 2020 on Glassdoor'] = df[' % of employees who approve of the CEO as of May 6, 2020 on Glassdoor'].replace("%","").astype(float)
df.dtypes
# Out:
# Company Name                                                              object
#  % of employees who would recommend this company to a friend             float64
#  % of employees who approve of the CEO as of May 6, 2020 on Glassdoor    float64
# 2020 CRN 100 Categories                                                   object
# dtype: object

# %%
cleaned_df = df.dropna()
cleaned_df
# Out:
#                      Company Name  \
# 0                        Fivetran
# 1                       Matillion
# 2                  Splice Machine
# 3                         Dataiku
# 4                         AtScale
# ..                            ...
# 96        Pepperdata - 11 reviews
# 99             Striim - 9 reviews
# 101         Timescale - 6 reviews
# 102      Unravel Data - 7 reviews
# 103  Yellowbrick Data - 2 reviews
#
#       % of employees who would recommend this company to a friend   \
# 0                                                100.0
# 1                                                100.0
# 2                                                100.0
# 3                                                 99.0
# 4                                                 98.0
# ..                                                 ...
# 96                                                82.0
# 99                                                89.0
# ...

# %%
catComp = cleaned_df[['Company Name',' % of employees who would recommend this company to a friend ', '2020 CRN 100 Categories ']]
catComp
catComp = catComp[(catComp[' % of employees who would recommend this company to a friend '] >= 80)] 
           
print(catComp.count())
catComp
# Out:
# Company Name                                                     43
#  % of employees who would recommend this company to a friend     43
# 2020 CRN 100 Categories                                          43
# dtype: int64
#                      Company Name  \
# 0                        Fivetran
# 1                       Matillion
# 2                  Splice Machine
# 3                         Dataiku
# 4                         AtScale
# 5                         Alation
# 6                         Diyotta
# 7                        Collibra
# 8                       Confluent
# 9                      Databricks
# 10                          Erwin
# 11                     InfluxData
# 12                            SAP
# 13                    ThoughtSpot
# 14                      Couchbase
# 15                        MongoDB
# 16                     Redis Labs
# 17                     StreamSets
# 18                         Qubole
# 19                   Google Cloud
# ...

# %%
catComp.pivot('Company Name', '2020 CRN 100 Categories ',
              ' % of employees who would recommend this company to a friend ').plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="1115">
