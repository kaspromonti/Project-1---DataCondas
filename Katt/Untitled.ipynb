# %%
# %matplotlib notebook

# %%
# Dependencies and set up
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# File path and read csv
pathFile = "Resources/glassdoor_big-data-business-analytics-company-ranking-05-06-2020-final.csv"
df = pd.read_csv(pathFile)
df
# Out:
#                      Company Name  \
# 0                        Fivetran
# 1                       Matillion
# 2                  Splice Machine
# 3                         Dataiku
# 4                         AtScale
# ..                            ...
# 99             Striim - 9 reviews
# 100           Tellius - 9 reviews
# 101         Timescale - 6 reviews
# 102      Unravel Data - 7 reviews
# 103  Yellowbrick Data - 2 reviews
#
#      % of employees who would recommend this company to a friend   \
# 0                                                 100%
# 1                                                 100%
# 2                                                 100%
# 3                                                  99%
# 4                                                  98%
# ..                                                 ...
# 99                                                 89%
# 100                                               100%
# 101                                               100%
# 102                                               100%
# 103                                               100%
#
#      % of employees who approve of the CEO as of May 6, 2020 on Glassdoor  \
# 0                                                 100%
# 1                                                 100%
# 2                                                 100%
# 3                                                 100%
# 4                                                 100%
# ..                                                 ...
# 99                                                 87%
# 100                                                NaN
# 101                                               100%
# 102                                               100%
# 103                                               100%
#
#                      2020 CRN 100 Categories
# 0        Data Management And Integration Tool
# 1        Data Management And Integration Tool
# 2                            Database Systems
# 3    Data Science And Machine Learning Tools
# 4                          Business Analytics
# ..                                        ...
# 99       Data Management And Integration Tool
# 100                        Business Analytics
# 101                          Database Systems
# 102      Data Management And Integration Tool
# 103            Big Data Systems And Platforms
#
# [104 rows x 4 columns]
